# %% [markdown]
# # CellRegPy — Full Pipeline Demo (Dual-Model Final Registration)
#
# This notebook runs the *full* `CellRegPy` pipeline on a mouse folder (session subfolders),
# and **enforces the Stage‑6 dual-model final registration**:
#
# 1. **Centroid-distance probabilistic model** drives clustering
# 2. **Spatial correlation** is used only as a **post-hoc veto** (floor cutoff, default **0.5**)
# 3. **Intersection over union** is used only in the rare cases where two images are near perfectly aligned (>0.9) to prevent mixed model failure
#
# During the run, figures are generated (matching the `demo_validate_alignment` figure set),
# but **Stage 4/5 plots are omitted**. Instead, a **Stage 6 (dual)** summary is saved per FOV:
# - centroid distance histogram (accepted vs vetoed)
# - spatial correlation histogram (accepted vs vetoed, floor shown)
# - final registered projections + pairwise overlap
#
# All figures are saved to:
# `<mouse_folder>/1_CellReg/FOV*/Figures/`
# and are **closed automatically** when `figures_visibility='off'` to avoid graphics crashes.

# %%
from pathlib import Path
import sys

# If you are running this notebook from the repo root, keep this.
# Otherwise, set this to the folder that contains cellregpy.py
repo_root = Path.cwd()
sys.path.insert(0, str(repo_root))

from cellregpy import CellRegConfig, run_pipeline

# %%
# ---- USER INPUT ----
mouse_folder = Path(r"C:\Users\spell\SpellmanLab Dropbox\OtherData\Manuscripts\in prep\L6CTopto_panneuronal_experiment\data\subjects_L6REstim\L629_M_LeftPFC_L6REChrimson_Panrec")  # e.g. r"C:\...\L612_F_RightPFC_..."

# Optional config overrides
cfg = CellRegConfig()
cfg.microns_per_pixel = 2.0
cfg.maximal_distance = 14.0     # µm
cfg.p_same_threshold = 0.5

# optional tuning
cfg.auto_simple_on_high_similarity = True
cfg.auto_simple_raw_corr_threshold = 0.90
cfg.auto_simple_aligned_corr_threshold = 0.95
cfg.auto_simple_method = "iou_hungarian"

cfg.simple_mask_threshold = 0.20     # binarize ROI at 20% of max
cfg.simple_iou_threshold  = 0.25     # accept match if IoU >= 0.25
cfg.simple_dist_threshold_um = 6.0   # accept match if centroid dist <= 6 µm
cfg.simple_cost_beta = 0.25          # distance penalty weight in assignment

# Run settings
spatial_corr_floor = 0.5
save_figures = True
figures_visibility = "on"        # "off" = save+close ; "on" = display
cfg.test_run = False

# %%
# ---- RUN FULL PIPELINE (dual-model enforced inside run_pipeline) ----
mouse_table, mouse_data = run_pipeline(
    mouse_folder,
    cfg=cfg,
    spatial_corr_floor=spatial_corr_floor,
    save_figures=save_figures,
    figures_visibility=figures_visibility,
    export_csv=True,
)

print("mouse_table shape:", mouse_table.shape)
print("mouse_table columns:", list(mouse_table.columns))
print("n sessions:", mouse_table["Session"].nunique())

# show how many cells per session (top 10)
(mouse_table.groupby("Session")
           .size()
           .sort_values(ascending=False)
           .head(10)
           .to_frame("n_cells"))
# Out:
# Processing: C:\Users\spell\SpellmanLab Dropbox\OtherData\Manuscripts\in prep\L6CTopto_panneuronal_experiment\data\subjects_L6REstim\L629_M_LeftPFC_L6REChrimson_Panrec
# Beginning processing: C:\Users\spell\SpellmanLab Dropbox\OtherData\Manuscripts\in prep\L6CTopto_panneuronal_experiment\data\subjects_L6REstim\L629_M_LeftPFC_L6REChrimson_Panrec
# Stage 1: Loading 2 sessions
# Loading mean images and iscell data...
# Building spatial-footprint projection images (iscell-filtered)...
#   Loaded footprints from key 'footprints'
#   Loaded footprints from key 'footprints'
# Adjusting FOV sizes...
# Finding alignable sessions...
#   Testing session 1/2 as reference
#   Testing session 2/2 as reference
# Saving alignment graph to C:\Users\spell\SpellmanLab Dropbox\OtherData\Manuscripts\in prep\L6CTopto_panneuronal_experiment\data\subjects_L6REstim\L629_M_LeftPFC_L6REChrimson_Panrec\1_CellReg\alignable_sessions_graph.png
# Removing redundancies...
#   Kept 1/2 FOVs
# Working on FOV 1/1
#   Registering 2 sessions...
#   Loaded footprints from key 'footprints'
#   Loaded footprints from key 'footprints'
# Normalizing spatial footprints...
#   Session 1/2
#   Session 2/2
# Adjusting FOV sizes...
# Computing footprint projections...
#   Session 1/2
#   Session 2/2
# Computing centroid locations...
#   Session 1/2
#   Session 2/2
#   Aligning cells to reference coordinate system...
#   translation  (out=False): hp=0.8965 | tx=0.0, ty=0.0, rot=0.00°, sx=1.0000, sy=1.0000
#   rigid        (out=False): hp=0.9071 | tx=0.7, ty=0.6, rot=-0.00°, sx=1.0000, sy=1.0000
#   similarity   (out=False): hp=0.9084 | tx=0.6, ty=0.6, rot=-0.00°, sx=1.0006, sy=1.0006
#   affine       (out=False): hp=0.9160 | tx=-0.3, ty=0.4, rot=0.03°, sx=1.0000, sy=1.0011, shear=-90.22°
#
#   ╔══ Alignment Scoreboard ════════════════════════════════════
#   ║ Method          Out        HP        LP        BP   Δ vs id
#   ╟─────────────────────────────────────────────────────────────
#   ║ ★identity        N  0.9161    -inf    -inf  +0.0000
#   ║  translation     N  0.8965    -inf    -inf  -0.0197
#   ║  rigid           N  0.9071    -inf    -inf  -0.0090
#   ║  similarity      N  0.9084    -inf    -inf  -0.0077
#   ║  affine          N  0.9160    -inf    -inf  -0.0001
#   ╚══════════════════════════════════════════════════════════════
#   Winner: identity (highpass), score=0.9161
#   No improvement with initial filter mode, trying all filter modes...
#   translation  (out=False): hp=0.7111 | tx=0.0, ty=4.0, rot=0.00°, sx=1.0000, sy=1.0000
#   rigid        (out=False): hp=0.7331 | tx=1.5, ty=4.4, rot=0.01°, sx=1.0000, sy=1.0000
#   similarity   (out=False): hp=0.7338 | tx=1.5, ty=4.2, rot=0.02°, sx=1.0005, sy=1.0005
#   affine       (out=False): hp=0.7473 | tx=-0.6, ty=1.9, rot=0.27°, sx=1.0012, sy=1.0040, shear=-90.12°
#
#   ╔══ Alignment Scoreboard ════════════════════════════════════
#   ║ Method          Out        HP        LP        BP   Δ vs id
#   ╟─────────────────────────────────────────────────────────────
#   ║  identity        N  0.5106    -inf    -inf  +0.0000
#   ║  translation     N  0.7111    -inf    -inf  +0.2005
#   ║  rigid           N  0.7331    -inf    -inf  +0.2226
#   ║  similarity      N  0.7338    -inf    -inf  +0.2232
#   ║ ★affine          N  0.7473    -inf    -inf  +0.2367
#   ╚══════════════════════════════════════════════════════════════
#   Winner: affine (highpass), score=0.7473
#   ✓ Alignment ACCEPTED: raw corr aligned=0.7472 > unaligned=0.5182
#     Session 2: source=mean_image, method=mean:identity (fp_refine_rejected:affine), peak=0.990, dx=0.0, dy=0.0, rot=0.00°
#   ⚡ High similarity detected (median raw corr=0.980, median aligned corr=0.980, median peak=0.990).
#   Switching to SIMPLE IoU+Hungarian registration (skipping probabilistic CellReg modeling).
# mouse_table shape: (281, 7)
# mouse_table columns: ['MouseName', 'Session', 'UnixTime', 'suite2pID', 'cellRegID', 'fovID', 'SessionPath']
# n sessions: 2
# C:\Users\spell\SpellmanLab Dropbox\timspellman\Python\John\CellRegPy\cellregpy\cellregpy.py:3288: UserWarning: Could not save mouse_table.mat: Could not convert None (type <class 'NoneType'>) to array
#   warnings.warn(f"Could not save mouse_table.mat: {e}")
#                     n_cells
# Session
# SEDS_day22_optoRec      149
# SEDS_day21_optoRec      132

# %%
# path to fall.mat
import numpy as np
import os
ops1 = np.load(os.path.join(mouse_data['L629_M_LeftPFC_L6REChrimson_Panrec']['sessions']['SEDS_day21_optoRec']['plane0_path'],'ops.npy'), allow_pickle=True).item()
ops2 = np.load(os.path.join(mouse_data['L629_M_LeftPFC_L6REChrimson_Panrec']['sessions']['SEDS_day22_optoRec']['plane0_path'],'ops.npy'), allow_pickle=True).item()

# %%
ops1['meanImg']-ops2['meanImg']
# Out:
# array([[-14.209404 , -14.074905 , -13.527443 , ..., -12.522507 ,
#         -13.481583 , -14.128086 ],
#        [-14.698128 , -14.6050415, -14.0277405, ..., -12.7840805,
#         -13.81332  , -14.513447 ],
#        [-15.6892395, -15.404869 , -14.9242935, ..., -12.828247 ,
#         -14.044975 , -14.725876 ],
#        ...,
#        [-13.981407 , -13.7391205, -13.330418 , ..., -10.050507 ,
#         -11.755383 , -12.952644 ],
#        [-13.873825 , -13.594769 , -13.233978 , ..., -10.203152 ,
#         -11.9004135, -12.978519 ],
#        [-13.831516 , -13.519844 , -13.083141 , ..., -10.590981 ,
#         -12.084297 , -13.046005 ]], dtype=float32)

# %%
import matplotlib.pyplot as plt
plt.imshow(ops1['meanImg']-ops2['meanImg'], cmap='gray')

# %%
mouse_table
# Out:
#                               MouseName             Session UnixTime  \
# 0    L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day21_optoRec     None
# 1    L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day21_optoRec     None
# 2    L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day21_optoRec     None
# 3    L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day21_optoRec     None
# 4    L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day21_optoRec     None
# ..                                  ...                 ...      ...
# 276  L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day22_optoRec     None
# 277  L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day22_optoRec     None
# 278  L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day22_optoRec     None
# 279  L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day22_optoRec     None
# 280  L629_M_LeftPFC_L6REChrimson_Panrec  SEDS_day22_optoRec     None
#
#      suite2pID  cellRegID fovID  \
# 0            1          1   [1]
# 1            2          2   [1]
# 2            5          3   [1]
# 3            7          4   [1]
# 4            8          5   [1]
# ..         ...        ...   ...
# 276        269        267   [1]
# 277        270        268   [1]
# 278        272        269   [1]
# 279        275        270   [1]
# 280        279        271   [1]
#
#                                            SessionPath
# 0    C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 1    C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 2    C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 3    C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 4    C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# ..                                                 ...
# 276  C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 277  C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 278  C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 279  C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
# 280  C:\Users\spell\SpellmanLab Dropbox\OtherData\M...
#
# [281 rows x 7 columns]

# %%
# ---- Wide table (nice for MATLAB) ----
wide = (mouse_table
        .pivot_table(index="cellRegID", columns="Session", values="suite2pID",
                     aggfunc="first", fill_value=0)
        .sort_index())
print("wide shape:", wide.shape)
# preview up to first 10 cellRegIDs and up to 10 sessions
wide.iloc[:10, :min(10, wide.shape[1])]
# Out:
# wide shape: (271, 2)
# Session    SEDS_day21_optoRec  SEDS_day22_optoRec
# cellRegID
# 1                           1                   0
# 2                           2                   0
# 3                           5                   0
# 4                           7                   2
# 5                           8                   0
# 6                          10                   0
# 7                          15                   0
# 8                          16                   0
# 9                          19                   0
# 10                         20                   0

# %%
# ---- Preview Stage 6 figures for the first FOV (if present) ----
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

cellreg_root = mouse_folder / "1_CellReg"
fov_dirs = sorted([p for p in cellreg_root.glob("FOV*") if p.is_dir()])

if not fov_dirs:
    print("No FOV folders found under:", cellreg_root)
else:
    fig_dir = fov_dirs[0] / "Figures"
    print("Previewing figures in:", fig_dir)

    # Stage 6 hist + projections are the most informative for the dual workflow
    candidates = [
        fig_dir / "Stage 6 - dual histograms.png",
        fig_dir / "Stage 6 (dual) - registered projections.png",
        fig_dir / "Stage 6 - pairwise session overlap.png",
    ]

    for p in candidates:
        if p.exists():
            img = mpimg.imread(p)
            plt.figure(figsize=(12, 6))
            plt.imshow(img)
            plt.axis("off")
            plt.title(p.name)
            plt.show()
        else:
            print("Missing:", p.name)
# Out:
# Previewing figures in: C:\Users\spell\SpellmanLab Dropbox\OtherData\Manuscripts\in prep\L6CTopto_panneuronal_experiment\data\subjects_L6REstim\L629_M_LeftPFC_L6REChrimson_Panrec\1_CellReg\FOV1\Figures
# Missing: Stage 6 (dual) - registered projections.png
# Missing: Stage 6 - pairwise session overlap.png

# %% [markdown]
# ## Where outputs go
#
# - **Per‑FOV results:** `<mouse_folder>/1_CellReg/FOV*/Results/`
#   - `cell_to_index_map.npy` (FINAL, post spatial-floor veto)
#   - `cell_to_index_map_pre_spatial_floor.npy` (centroid-primary, pre-veto)
#   - `registration_results.npy` (includes veto stats / arrays)
#
# - **Per‑FOV figures:** `<mouse_folder>/1_CellReg/FOV*/Figures/`
#   - Stage 1–3 figures (as in `demo_validate_alignment`)
#   - **Stage 6 (dual) summary** (replaces Stage 4/5 plotting)
#
# - **Mouse table exports:** `<mouse_folder>/1_CellReg/`
#   - `mouse_table.csv`
#   - `mouse_table_wide.csv`
#   - plus existing `mouse_table.mat` / `mouse_table.pkl`
